# %% [markdown]
# ## Environment

# %%
# !pip install pycocotools
# !pip install albumentations

# %%
import os

# %%
# clone the git repository and set it as the working directory
! git clone https://github.com/kimiaf1998/Parking-Space-Detection.git
os.chdir('Parking-Space-Detection/Modules/Space')

# %%
# import dataset, models, and training utils.
from dataset import acpds
from utils_funcs.engine import train_model
from models.rcnn_fpn import create_model

# %%
# set device
# import torchdevice = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# ### Train model

# %%
# load dataset
train_ds, valid_ds, test_ds = acpds.create_datasets('dataset/data', 1, res=1800)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
### best epoch 29 62.2%

# %%
# train model
out_dir = 'Results'
train_model(create_model(visionT=False), train_ds, valid_ds, test_ds, out_dir, device, epochs=30, lr=0.00008)
# Out:
# creating file headers in  ./MyFRCNN_model_5/LR_8e-05_AdamW_CosineAnnealingLR
# *********** training step ***********
# /home/kimia/.local/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# ...

# %%
torch.cuda.empty_cache()
